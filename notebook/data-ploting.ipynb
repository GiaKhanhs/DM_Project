# %% [markdown]
# #FINAL

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Model": ["LDA", "SVM", "LR", "ET", "RF"],
    "Work": [0.968, 1.000, 1.000, 1.000, 1.000],
    "Study": [0.951, 1.000, 1.000, 1.000, 1.000],
    "Self": [0.957, 1.000, 1.000, 1.000, 1.000],
    "Family": [0.943, 1.000, 0.844, 1.000, 1.000],
    "Love": [0.989, 0.989, 1.000, 1.000, 0.989]
}

df = pd.DataFrame(data)

# Set the Model column as the index for the DataFrame
df.set_index("Model", inplace=True)

# Plot the data as a line chart
plt.figure(figsize=(10, 6))
for model in df.index:
    plt.plot(df.columns, df.loc[model], marker='o', label=model)

# Add labels and a legend
plt.xlabel("Categories")
plt.ylabel("Accuracy Scores")
plt.title("Model Performance on Training Dataset")
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Model": ["LDA", "SVM", "LR", "ET", "RF"],
    "Work": [0.930, 0.977, 0.965, 0.802, 0.814],
    "Study": [0.958, 0.986, 0.986, 0.845, 0.803],
    "Self": [0.879, 0.948, 0.879, 0.845, 0.828],
    "Family": [0.871, 0.839, 0.516, 0.742, 0.839],
    "Love": [0.909, 0.773, 0.773, 0.818, 0.818]
}

df = pd.DataFrame(data)

# Set the Model column as the index for the DataFrame
df.set_index("Model", inplace=True)

# Plot the data as a line chart
plt.figure(figsize=(10, 6))
for model in df.index:
    plt.plot(df.columns, df.loc[model], marker='o', label=model)

# Add labels and a legend
plt.xlabel("Categories")
plt.ylabel("Accuracy Scores")
plt.title("Model Performance on Validation Dataset")
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Model": ["LDA", "SVM", "LR", "ET", "RF"],
    "Work": [0.938, 0.979, 0.979, 0.875, 0.875],
    "Study": [0.974, 0.974, 0.949, 0.872, 0.821],
    "Self": [0.969, 0.844, 0.875, 0.750, 0.656],
    "Family": [1.000, 1.000, 0.647, 0.706, 0.706],
    "Love": [0.893, 0.857, 0.786, 0.750, 0.571]
}

df = pd.DataFrame(data)

# Set the Model column as the index for the DataFrame
df.set_index("Model", inplace=True)

# Plot the data as a line chart
plt.figure(figsize=(10, 6))
for model in df.index:
    plt.plot(df.columns, df.loc[model], marker='o', label=model)

# Add labels and a legend
plt.xlabel("Categories")
plt.ylabel("Accuracy Scores")
plt.title("Model Performance on Testing Dataset")
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# # Family

# %%
import pandas as pd

train = {
    "Model": ["LDA", "SVM", "LG", "ET", "RF"],
    90: [1, 1, 1, 1, 1],
    80: [0.851851852, 1, 0.888888889, 1, 1],
    70: [0.925, 1, 0.275, 1, 1],
    60: [0.925925926, 1, 0.685185185, 1, 1],
    50: [0.852941176, 1, 0.955882353, 1, 1],
    40: [0.925925926, 0.975308642, 0.864197531, 1, 1],
    30: [0.947368421, 1, 1, 1, 1],
    20: [0.962962963, 0.953703704, 1, 1, 1],
    10: [0.942622951, 1, 0.844262295, 1, 1]
}

train = pd.DataFrame(train)

# Set "Model" as the index
train.set_index("Model", inplace=True)

# Transpose the DataFrame for plotting
train = train.T

# Plot the data
plt.figure(figsize=(10, 6))
train.plot(kind='line', marker='o')
plt.title("Traing dataset")
plt.xlabel("The percentage of test dataset's size")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.grid(True)
plt.show()

# %%
import pandas as pd

valid = {
    "Model": ["LDA", "SVM", "LG", "ET", "RF"],
    90: [0.25, 0.25, 0.25, 0.25, 0.5],
    80: [0.428571429, 0.285714286, 0.285714286, 0.571428571, 0.428571429],
    70: [0.727272727, 0.545454545, 0.454545455, 0.909090909, 0.909090909],
    60: [0.642857143, 0.642857143, 0.571428571, 0.785714286, 0.571428571],
    50: [0.588235294, 0.588235294, 0.588235294, 0.764705882, 0.647058824],
    40: [0.666666667, 0.619047619, 0.476190476, 0.666666667, 0.761904762],
    30: [0.833333333, 0.708333333, 0.708333333, 0.791666667, 0.75],
    20: [0.821428571, 0.714285714, 0.678571429, 0.75, 0.785714286],
    10: [0.870967742, 0.838709677, 0.516129032, 0.741935484, 0.838709677]
}

valid = pd.DataFrame(valid)

# Set "Model" as the index
valid.set_index("Model", inplace=True)

# Transpose the DataFrame for plotting
valid = valid.T

# Plot the data
plt.figure(figsize=(10, 6))
valid.plot(kind='line', marker='o')
plt.title("Validation dataset")
plt.xlabel("The percentage of test dataset's size")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

test = {
    "Model": ["LDA", "SVM", "LG", "ET", "RF"],
    90: [0.431372549, 0.281045752, 0.37254902, 0.535947712, 0.450980392],
    80: [0.514705882, 0.522058824, 0.433823529, 0.647058824, 0.625],
    70: [0.697478992, 0.529411765, 0.210084034, 0.68907563, 0.630252101],
    60: [0.735294118, 0.519607843, 0.401960784, 0.725490196, 0.656862745],
    50: [0.647058824, 0.552941176, 0.6, 0.705882353, 0.635294118],
    40: [0.661764706, 0.75, 0.558823529, 0.75, 0.632352941],
    30: [0.980392157, 0.882352941, 0.764705882, 0.803921569, 0.666666667],
    20: [0.852941176, 0.823529412, 0.588235294, 0.735294118, 0.676470588],
    10: [1, 1, 0.647058824, 0.705882353, 0.705882353],
}

test = pd.DataFrame(test)

# Set "Model" as the index
test.set_index("Model", inplace=True)

# Transpose the DataFrame for plotting
test = test.T

# Plot the data
plt.figure(figsize=(10, 6))
test.plot(kind='line', marker='o')
plt.title("Testing dataset")
plt.xlabel("The percentage of test dataset's size")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.grid(True)
plt.show()

# %% [markdown]
# # Love

# %%
import pandas as pd
import matplotlib.pyplot as plt

train = {
    "Model": ["LDA", "SVM", "LG", "ET", "RF"],
    90: [1, 1, 1, 1, 1],
    80: [0.904761905, 1, 0.857142857, 1, 0.904761905],
    70: [1, 0.96875, 0.71875, 1, 1],
    60: [0.931818182, 1, 1, 1, 0.931818182],
    50: [0.945454545, 0.981818182, 0.872727273, 1, 0.945454545],
    40: [0.861538462, 1, 0.923076923, 1, 0.861538462],
    30: [0.960526316, 1, 1, 1, 0.960526316],
    20: [0.988636364, 0.988636364, 1, 1, 0.988636364],
    10: [0.97979798, 1, 1, 1, 0.97979798],
}


train = pd.DataFrame(train)

# Set "Model" as the index
train.set_index("Model", inplace=True)

# Transpose the DataFrame for plotting
train = train.T

# Plot the data
plt.figure(figsize=(10, 6))
train.plot(kind='line', marker='o')
plt.title("Traing dataset")
plt.xlabel("The percentage of test dataset's size")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.grid(True)
plt.show()

# %%
import pandas as pd

valid = {
    "Model": ["LDA", "SVM", "LG", "ET", "RF"],
    90: [0.333333333, 0.333333333, 0.333333333, 0.666666667, 0.333333333],
    80: [0.5, 0.666666667, 0.5, 0.5, 0.5],
    70: [0.888888889, 0.555555556, 0.777777778, 0.777777778, 0.666666667],
    60: [0.545454545, 0.545454545, 0.545454545, 0.636363636, 0.636363636],
    50: [0.714285714, 0.785714286, 0.571428571, 0.571428571, 0.428571429],
    40: [0.705882353, 0.705882353, 0.588235294, 0.823529412, 0.529411765],
    30: [0.8, 0.85, 0.85, 0.65, 0.75],
    20: [0.909090909, 0.772727273, 0.772727273, 0.818181818, 0.818181818],
    10: [0.92, 0.84, 0.76, 0.76, 0.68],
}

valid = pd.DataFrame(valid)

# Set "Model" as the index
valid.set_index("Model", inplace=True)

# Transpose the DataFrame for plotting
valid = valid.T

# Plot the data
plt.figure(figsize=(10, 6))
valid.plot(kind='line', marker='o')
plt.title("Validation dataset")
plt.xlabel("The percentage of test dataset's size")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

test = {
    "Model": ["LDA", "SVM", "LG", "ET", "RF"],
    90: [0.584, 0.536, 0.432, 0.552, 0.44],
    80: [0.630630631, 0.522522523, 0.594594595, 0.612612613, 0.522522523],
    70: [0.793814433, 0.721649485, 0.432989691, 0.701030928, 0.628865979],
    60: [0.674698795, 0.674698795, 0.457831325, 0.65060241, 0.554216867],
    50: [0.826086957, 0.826086957, 0.695652174, 0.724637681, 0.623188406],
    40: [0.696428571, 0.821428571, 0.482142857, 0.75, 0.589285714],
    30: [0.857142857, 0.761904762, 0.714285714, 0.857142857, 0.761904762],
    20: [0.892857143, 0.857142857, 0.785714286, 0.75, 0.571428571],
    10: [0.785714286, 0.857142857, 0.642857143, 0.642857143, 0.5],
}

test = pd.DataFrame(test)

# Set "Model" as the index
test.set_index("Model", inplace=True)

# Transpose the DataFrame for plotting
test = test.T

# Plot the data
plt.figure(figsize=(10, 6))
test.plot(kind='line', marker='o')
plt.title("Testing dataset")
plt.xlabel("The percentage of test dataset's size")
plt.ylabel("Accuracy")
plt.legend(title="Model")
plt.grid(True)
plt.show()
